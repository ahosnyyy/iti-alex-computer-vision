# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, Concatenate, Dropout, Flatten, Dense, GlobalAveragePooling2D

# %%
def fire_module(x, squeeze, expand):
    squeeze = Conv2D(filters=squeeze, kernel_size=(1, 1), activation='relu', padding='same')(x)
    expand_1x1 = Conv2D(filters=expand, kernel_size=(1, 1), activation='relu', padding='same')(squeeze)
    expand_3x3 = Conv2D(filters=expand, kernel_size=(3, 3), activation='relu', padding='same')(squeeze)
    output = Concatenate(axis=-1)([expand_1x1, expand_3x3])
    return output

# %%
def SqueezeNet(input_shape=(224,224,3), num_classes=10):
    input_tensor = Input(shape=input_shape)
    x = Conv2D(filters=64, kernel_size=(3, 3), strides=(2, 2), activation='relu', padding='valid')(input_tensor)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(x)
    
    x = fire_module(x, squeeze=16, expand=64)
    x = fire_module(x, squeeze=16, expand=64)
    x = fire_module(x, squeeze=32, expand=128)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(x)
    
    x = fire_module(x, squeeze=32, expand=128)
    x = fire_module(x, squeeze=48, expand=192)
    x = fire_module(x, squeeze=48, expand=192)
    x = fire_module(x, squeeze=64, expand=256)
    x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(x)
    
    x = fire_module(x, squeeze=64, expand=256)
    x = Dropout(0.5)(x)
    x = Conv2D(filters=num_classes, kernel_size=(1, 1), activation='relu', padding='same')(x)
    x = GlobalAveragePooling2D()(x)
    output_tensor = Dense(units=num_classes, activation='softmax')(x)
    
    model = Model(inputs=input_tensor, outputs=output_tensor)
    return model

# %%
squeeze_net = SqueezeNet()
squeeze_net.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_26 (Conv2D)             (None, 111, 111, 64  1792        ['input_2[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 55, 55, 64)  0           ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 55, 55, 16)   1040        ['max_pooling2d_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 55, 55, 64)   1088        ['conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 55, 55, 64)   9280        ['conv2d_27[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 55, 55, 128)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 55, 55, 16)   2064        ['concatenate_8[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 55, 55, 64)   1088        ['conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 55, 55, 64)   9280        ['conv2d_30[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 55, 55, 128)  0           ['conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 55, 55, 32)   4128        ['concatenate_9[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 55, 55, 128)  4224        ['conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 55, 55, 128)  36992       ['conv2d_33[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 55, 55, 256)  0           ['conv2d_34[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 27, 27, 256)  0          ['concatenate_10[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 27, 27, 32)   8224        ['max_pooling2d_4[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 27, 27, 128)  4224        ['conv2d_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 27, 27, 128)  36992       ['conv2d_36[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 27, 27, 256)  0           ['conv2d_37[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 27, 27, 48)   12336       ['concatenate_11[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 27, 27, 192)  9408        ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 27, 27, 192)  83136       ['conv2d_39[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 27, 27, 384)  0           ['conv2d_40[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 27, 27, 48)   18480       ['concatenate_12[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 27, 27, 192)  9408        ['conv2d_42[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 27, 27, 192)  83136       ['conv2d_42[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 27, 27, 384)  0           ['conv2d_43[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 27, 27, 64)   24640       ['concatenate_13[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 27, 27, 256)  16640       ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 27, 27, 256)  147712      ['conv2d_45[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 27, 27, 512)  0           ['conv2d_46[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 13, 13, 512)  0          ['concatenate_14[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 13, 13, 64)   32832       ['max_pooling2d_5[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 13, 13, 256)  16640       ['conv2d_48[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 13, 13, 256)  147712      ['conv2d_48[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 13, 13, 512)  0           ['conv2d_49[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  dropout_1 (Dropout)            (None, 13, 13, 512)  0           ['concatenate_15[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 13, 13, 1000  513000      ['dropout_1[0][0]']
#                                 )
#
#  global_average_pooling2d (Glob  (None, 1000)        0           ['conv2d_51[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1000)         1001000     ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 2,236,496
# Trainable params: 2,236,496
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# As you can see in the first line of the function, using the Keras Functional API, ```tf.keras.layers.Conv2D()``` instantiates a convolutional layer which is then called with the input x. We can slightly transform the fire() function so that it uses the same semantics:

# %%
def fire(x, squeeze, expand):
  y = Conv2D(filters=squeeze, kernel_size=1, activation='relu', padding='same')(x)
  y1 = Conv2D(filters=expand, kernel_size=1, activation='relu', padding='same')(y)
  y3 = Conv2D(filters=expand, kernel_size=3, activation='relu', padding='same')(y)
  return Concatenate(axis=-1)([y1, y3])

# %%
def fire_module(squeeze, expand):
  return lambda x: fire(x, squeeze, expand)

# %%
def SqueezeNet(input_shape=(224,224,3), num_classes=10):
  input_tensor = Input(shape=input_shape)
  x = Conv2D(filters=64, kernel_size=(3, 3), strides=(2, 2), activation='relu', padding='valid')(input_tensor)
  x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(x)

  x = fire_module(squeeze=16, expand=64)(x)
  x = fire_module(squeeze=16, expand=64)(x)
  x = fire_module(squeeze=32, expand=128)(x)
  x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(x)

  x = fire_module(squeeze=32, expand=128)(x)
  x = fire_module(squeeze=48, expand=192)(x)
  x = fire_module(squeeze=48, expand=192)(x)
  x = fire_module(squeeze=64, expand=256)(x)
  x = MaxPooling2D(pool_size=(3, 3), strides=(2, 2))(x)

  x = fire_module(squeeze=64, expand=256)(x)

  x = Dropout(0.5)(x)
  x = Conv2D(filters=num_classes, kernel_size=(1, 1), activation='relu', padding='same')(x)
  x = GlobalAveragePooling2D()(x)
  output_tensor = Dense(units=num_classes, activation='softmax')(x)

  model = Model(inputs=input_tensor, outputs=output_tensor)

  return model

# %%
squeeze_net = SqueezeNet()
squeeze_net.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_52 (Conv2D)             (None, 224, 224, 32  896         ['input_3[0][0]']
#                                 )
#
#  conv2d_53 (Conv2D)             (None, 224, 224, 16  528         ['conv2d_52[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 224, 224, 32  544         ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_55 (Conv2D)             (None, 224, 224, 32  4640        ['conv2d_53[0][0]']
#                                 )
#
#  concatenate_16 (Concatenate)   (None, 224, 224, 64  0           ['conv2d_54[0][0]',
#                                 )                                 'conv2d_55[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 112, 112, 64  0          ['concatenate_16[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 112, 112, 48  3120        ['max_pooling2d_6[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 112, 112, 96  4704        ['conv2d_56[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 112, 112, 96  41568       ['conv2d_56[0][0]']
#                                 )
#
#  concatenate_17 (Concatenate)   (None, 112, 112, 19  0           ['conv2d_57[0][0]',
#                                 2)                                'conv2d_58[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 56, 56, 192)  0          ['concatenate_17[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 56, 56, 64)   12352       ['max_pooling2d_7[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 56, 56, 128)  8320        ['conv2d_59[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 56, 56, 128)  73856       ['conv2d_59[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 56, 56, 256)  0           ['conv2d_60[0][0]',
#                                                                   'conv2d_61[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 56, 56, 80)   20560       ['concatenate_18[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 56, 56, 160)  12960       ['conv2d_62[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 56, 56, 160)  115360      ['conv2d_62[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 56, 56, 320)  0           ['conv2d_63[0][0]',
#                                                                   'conv2d_64[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 56, 56, 96)   30816       ['concatenate_19[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 56, 56, 192)  18624       ['conv2d_65[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 56, 56, 192)  166080      ['conv2d_65[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 56, 56, 384)  0           ['conv2d_66[0][0]',
#                                                                   'conv2d_67[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 28, 28, 384)  0          ['concatenate_20[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 28, 28, 112)  43120       ['max_pooling2d_8[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 28, 28, 224)  25312       ['conv2d_68[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 28, 28, 224)  226016      ['conv2d_68[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 28, 28, 448)  0           ['conv2d_69[0][0]',
#                                                                   'conv2d_70[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 28, 28, 128)  57472       ['concatenate_21[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 28, 28, 256)  33024       ['conv2d_71[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 28, 28, 256)  295168      ['conv2d_71[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 28, 28, 512)  0           ['conv2d_72[0][0]',
#                                                                   'conv2d_73[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 28, 28, 160)  82080       ['concatenate_22[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 28, 28, 320)  51520       ['conv2d_74[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 28, 28, 320)  461120      ['conv2d_74[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 28, 28, 640)  0           ['conv2d_75[0][0]',
#                                                                   'conv2d_76[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 14, 14, 640)  0          ['concatenate_23[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 14, 14, 192)  123072      ['max_pooling2d_9[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 14, 14, 384)  74112       ['conv2d_77[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 14, 14, 384)  663936      ['conv2d_77[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 14, 14, 768)  0           ['conv2d_78[0][0]',
#                                                                   'conv2d_79[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 14, 14, 224)  172256      ['concatenate_24[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 14, 14, 448)  100800      ['conv2d_80[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 14, 14, 448)  903616      ['conv2d_80[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 14, 14, 896)  0           ['conv2d_81[0][0]',
#                                                                   'conv2d_82[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 7, 7, 896)   0           ['concatenate_25[0][0]']
#  )
#
#  conv2d_83 (Conv2D)             (None, 7, 7, 256)    229632      ['max_pooling2d_10[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 7, 7, 512)    131584      ['conv2d_83[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 7, 7, 512)    1180160     ['conv2d_83[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 7, 7, 1024)   0           ['conv2d_84[0][0]',
#                                                                   'conv2d_85[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['concatenate_26[0][0]']
#  obalAveragePooling2D)
#
#  dense_1 (Dense)                (None, 10)           10250       ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 5,379,178
# Trainable params: 5,379,178
# Non-trainable params: 0
# __________________________________________________________________________________________________
