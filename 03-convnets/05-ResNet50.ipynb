# %%
import numpy as np
import os
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D,MaxPool2D
from tensorflow.keras.initializers import glorot_uniform

# %%
def identity_block(X, f, filters):

    F1, F2, F3 = filters

    X_shortcut = X
   
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3)(X)

    X = Add()([X, X_shortcut])# SKIP Connection
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, s=2):

    F1, F2, F3 = filters

    X_shortcut = X

    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3)(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3)(X)

    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3)(X_shortcut)

    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape=(224, 224, 3)):

    X_input = Input(input_shape)

    X = ZeroPadding2D((3, 3))(X_input)

    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    X = convolutional_block(X, f=3, filters=[64, 64, 256], s=1)
    X = identity_block(X, 3, [64, 64, 256])
    X = identity_block(X, 3, [64, 64, 256])


    X = convolutional_block(X, f=3, filters=[128, 128, 512], s=2)
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])
    X = identity_block(X, 3, [128, 128, 512])

    X = convolutional_block(X, f=3, filters=[256, 256, 1024], s=2)
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])
    X = identity_block(X, 3, [256, 256, 1024])

    X = convolutional_block(X, f=3, filters=[512, 512, 2048],s=2)
    X = identity_block(X, 3, [512, 512, 2048])
    X = identity_block(X, 3, [512, 512, 2048])

    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)

    X = Flatten()(X)
    X = Dense(256, activation='relu', kernel_initializer=glorot_uniform(seed=0))(X)
    X = Dense(128, activation='relu', kernel_initializer=glorot_uniform(seed=0))(X)
    X = Dense( 1,activation='sigmoid', kernel_initializer=glorot_uniform(seed=0))(X)

    model = Model(inputs=X_input, outputs=X, name='ResNet50')
    
    return model

# %%
resnet50_model = ResNet50(input_shape=(224, 224, 3))
resnet50_model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  zero_padding2d_2 (ZeroPadding2  (None, 230, 230, 3)  0          ['input_3[0][0]']
#  D)
#
#  conv1 (Conv2D)                 (None, 112, 112, 64  9472        ['zero_padding2d_2[0][0]']
#                                 )
#
#  bn_conv1 (BatchNormalization)  (None, 112, 112, 64  256         ['conv1[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 112, 112, 64  0           ['bn_conv1[0][0]']
#                                 )
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 55, 55, 64)  0           ['activation_2[0][0]']
#
#  conv2d (Conv2D)                (None, 55, 55, 64)   4160        ['max_pooling2d_2[0][0]']
#
#  batch_normalization (BatchNorm  (None, 55, 55, 64)  256         ['conv2d[0][0]']
#  alization)
#
#  activation_3 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 55, 55, 64)   36928       ['activation_3[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 55, 55, 256)  16640       ['activation_4[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 55, 55, 256)  16640       ['max_pooling2d_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 55, 55, 256)  1024       ['conv2d_2[0][0]']
#  rmalization)
#
#  batch_normalization_3 (BatchNo  (None, 55, 55, 256)  1024       ['conv2d_3[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 55, 55, 256)  0           ['batch_normalization_2[0][0]',
#                                                                   'batch_normalization_3[0][0]']
#
#  activation_5 (Activation)      (None, 55, 55, 256)  0           ['add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 55, 55, 64)   16448       ['activation_5[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 55, 55, 64)   36928       ['activation_6[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 55, 55, 256)  16640       ['activation_7[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 55, 55, 256)  1024       ['conv2d_6[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 55, 55, 256)  0           ['batch_normalization_6[0][0]',
#                                                                   'activation_5[0][0]']
#
#  activation_8 (Activation)      (None, 55, 55, 256)  0           ['add_1[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 55, 55, 64)   16448       ['activation_8[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 55, 55, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 55, 55, 64)   36928       ['activation_9[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 55, 55, 64)  256         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 55, 55, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 55, 55, 256)  16640       ['activation_10[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 55, 55, 256)  1024       ['conv2d_9[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 55, 55, 256)  0           ['batch_normalization_9[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_11 (Activation)     (None, 55, 55, 256)  0           ['add_2[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 128)  32896       ['activation_11[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_12[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_13[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 512)  131584      ['activation_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_13[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_12[0][0]',
#                                                                   'batch_normalization_13[0][0]']
#
#  activation_14 (Activation)     (None, 28, 28, 512)  0           ['add_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_14[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_15[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_16[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_16[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_16[0][0]',
#                                                                   'activation_14[0][0]']
#
#  activation_17 (Activation)     (None, 28, 28, 512)  0           ['add_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_17[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 128)  512        ['conv2d_17[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_18[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_19[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_19[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_19[0][0]',
#                                                                   'activation_17[0][0]']
#
#  activation_20 (Activation)     (None, 28, 28, 512)  0           ['add_5[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 128)  65664       ['activation_20[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 28, 128)  147584      ['activation_21[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 28, 28, 128)  512        ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 28, 28, 512)  66048       ['activation_22[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 28, 28, 512)  2048       ['conv2d_22[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['batch_normalization_22[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_23 (Activation)     (None, 28, 28, 512)  0           ['add_6[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 256)  131328      ['activation_23[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_24[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_25[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 1024  525312      ['activation_23[0][0]']
#                                 )
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_25[0][0]']
#  ormalization)                  )
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_26[0][0]']
#  ormalization)                  )
#
#  add_7 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_25[0][0]',
#                                 )                                 'batch_normalization_26[0][0]']
#
#  activation_26 (Activation)     (None, 14, 14, 1024  0           ['add_7[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_28[0][0]']
#                                 )
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_29[0][0]']
#  ormalization)                  )
#
#  add_8 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_29[0][0]',
#                                 )                                 'activation_26[0][0]']
#
#  activation_29 (Activation)     (None, 14, 14, 1024  0           ['add_8[0][0]']
#                                 )
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_31[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_32[0][0]']
#  ormalization)                  )
#
#  add_9 (Add)                    (None, 14, 14, 1024  0           ['batch_normalization_32[0][0]',
#                                 )                                 'activation_29[0][0]']
#
#  activation_32 (Activation)     (None, 14, 14, 1024  0           ['add_9[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  add_10 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_35[0][0]',
#                                 )                                 'activation_32[0][0]']
#
#  activation_35 (Activation)     (None, 14, 14, 1024  0           ['add_10[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_37[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  add_11 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_38[0][0]',
#                                 )                                 'activation_35[0][0]']
#
#  activation_38 (Activation)     (None, 14, 14, 1024  0           ['add_11[0][0]']
#                                 )
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 256)  262400      ['activation_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 256)  590080      ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 256)  1024       ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 1024  263168      ['activation_40[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 1024  4096       ['conv2d_41[0][0]']
#  ormalization)                  )
#
#  add_12 (Add)                   (None, 14, 14, 1024  0           ['batch_normalization_41[0][0]',
#                                 )                                 'activation_38[0][0]']
#
#  activation_41 (Activation)     (None, 14, 14, 1024  0           ['add_12[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 7, 7, 512)    524800      ['activation_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_43[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_43[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 7, 7, 2048)   2099200     ['activation_41[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_45[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_44[0][0]',
#                                                                   'batch_normalization_45[0][0]']
#
#  activation_44 (Activation)     (None, 7, 7, 2048)   0           ['add_13[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_44[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_46[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_45[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_46[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_48[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_48[0][0]',
#                                                                   'activation_44[0][0]']
#
#  activation_47 (Activation)     (None, 7, 7, 2048)   0           ['add_14[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 512)    1049088     ['activation_47[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 512)    2359808     ['activation_48[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 7, 7, 512)   2048        ['conv2d_50[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 2048)   1050624     ['activation_49[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 7, 7, 2048)  8192        ['conv2d_51[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 7, 7, 2048)   0           ['batch_normalization_51[0][0]',
#                                                                   'activation_47[0][0]']
#
#  activation_50 (Activation)     (None, 7, 7, 2048)   0           ['add_15[0][0]']
#
#  average_pooling2d (AveragePool  (None, 4, 4, 2048)  0           ['activation_50[0][0]']
#  ing2D)
#
#  flatten (Flatten)              (None, 32768)        0           ['average_pooling2d[0][0]']
#
#  dense (Dense)                  (None, 256)          8388864     ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 128)          32896       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 1)            129         ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 32,009,601
# Trainable params: 31,956,481
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
